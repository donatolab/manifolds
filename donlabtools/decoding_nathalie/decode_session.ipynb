# %%
# Saving settings
# %autosave 180
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
# %matplotlib inline

# Computing
import numpy as np

# Files
from utils_nathalie import Animal, ProjectionDecoder
# Out:
# Autosaving every 180 seconds
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Select the directory with the input data
main_dir = "/media/cat/4TB/donato/nathalie"
animal_id = "DON-007417"
#animal_id = "DON-007050"
session_id = "FS11"

#
ani = Animal(main_dir,
              animal_id,
              session_id)
# Out:
# ... processing location csv
# ...processing neural data...
# bin upphase:  (451, 36024)
# All DLC locations:  (36000, 2)
# Final locations shape:  (36000, 2)
# bin upphase:  (451, 36024)
# (36000, 451)
# 1255.6782 1258.1257
# DONE
# ...done...

# %%
# bayesian_decoder
ani.speed_threshold = 2 #Set a threshold for the speed
ani.use_place_cells = False
ani.shuffle = False
ani.data_split = 0.8
ani.predict_immobile = False
ani.remove_nonvisited_locs = True

#
ani.plot_bayesian_decoding = True
ani.bayesian_decoding()
# Out:
# Time moving:  1053.35 , time not moving:  746.65
# total time, total cells:  (21067, 451)
# length of moving period:  1053.35 sec
# Frames with non-zero activity:  839.3  sec.
# # cells with some activity in the period:  (406,)
# fitting cells: 100%|██████████| 406/406 [00:11<00:00, 36.63it/s]
# test loc >3cm from training set (removed)  1542 3.934643
# test loc >3cm from training set (removed)  1543 4.592774
# test loc >3cm from training set (removed)  1544 3.7200658
# test loc >3cm from training set (removed)  1582 3.3962166
# test loc >3cm from training set (removed)  2278 3.0272167
# decoding mobile: 100%|██████████| 4192/4192 [00:05<00:00, 825.52it/s]
