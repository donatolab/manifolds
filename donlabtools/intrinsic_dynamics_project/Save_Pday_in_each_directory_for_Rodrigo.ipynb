# %%
import matplotlib
# %matplotlib tk
# %autosave 180
# %load_ext autoreload
# %autoreload 2

import nest_asyncio
# %config Completer.use_jedi = False

#
import matplotlib.pyplot as plt
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# 
import numpy as np
import os
import scipy

# add root directory to be able to import packages
# todo: make all packages installable so they can be called/imported by environment
import sys
module_path = os.path.abspath(os.path.join('..'))
sys.path.append(module_path)

from utils.calcium import calcium
from utils.wheel import wheel
from utils.cohort import cohort
# Out:
# Autosaving every 180 seconds
# <style>.container { width:100% !important; }</style>

# %%
#######################################################
#######################################################
#######################################################

#
mouse_ids = [
    'DON-006084',
    'DON-006085',
    'DON-006087',
    
    'DON-009191',
    'DON-009192',
    'DON-010473',
    'DON-010477',
           
    'DON-002865',
    'DON-003165',
    'DON-003343',
    
    'DON-008497',
    'DON-008498',
    'DON-008499',  
    
]

#
PDays = [
    [19,28],
    [19,28],
    [24,33],
    
    [16,48],  # expression issues
    [15,60],  
    [16,33],
    [15,33],
    
    [90,100],
    [120,130],
    [150,160],
    
    [60,73],
    [60,73],
    [60,73],

]

# %%
#######################################################
#######################################################
#######################################################
import yaml

#
root_dir = '/media/cat/4TB1/donato/'

#
for mouse_id, PDay in zip(mouse_ids, PDays):
    print (mouse_id, PDay)
    
    fname_dir = os.path.join(root_dir, mouse_id)
    
    fnames = np.sort(os.listdir(fname_dir))
    
    print (fnames)
    
    ctr = int(PDay[0])
    for fname in fnames:
        fname_temp = os.path.join(root_dir,
                                  mouse_id,
                                  fname,
                                  'metadata.yaml')
        
        #
        print ("fname temp: ", fname_temp)

        dict_file = [{'PDay' : ctr}]

        with open(fname_temp, 'w') as file:
            documents = yaml.dump(dict_file, file)
    
        ctr+=1
# Out:
# DON-006084 [19, 28]
# ['20210519' '20210520' '20210521' '20210522' '20210523' '20210524'
#  '20210525' '20210526' '20210527' '20210528']
# fname temp:  /media/cat/4TB1/donato/DON-006084/20210519/metadata.yaml
# fname temp:  /media/cat/4TB1/donato/DON-006084/20210520/metadata.yaml
# fname temp:  /media/cat/4TB1/donato/DON-006084/20210521/metadata.yaml
# fname temp:  /media/cat/4TB1/donato/DON-006084/20210522/metadata.yaml
# fname temp:  /media/cat/4TB1/donato/DON-006084/20210523/metadata.yaml
# fname temp:  /media/cat/4TB1/donato/DON-006084/20210524/metadata.yaml
# fname temp:  /media/cat/4TB1/donato/DON-006084/20210525/metadata.yaml
# fname temp:  /media/cat/4TB1/donato/DON-006084/20210526/metadata.yaml
# fname temp:  /media/cat/4TB1/donato/DON-006084/20210527/metadata.yaml
# fname temp:  /media/cat/4TB1/donato/DON-006084/20210528/metadata.yaml
# DON-006085 [19, 28]
# ['20210519' '20210520' '20210521' '20210522' '20210523' '20210524'
#  '20210525' '20210526' '20210527' '20210528']
# ...

# %%
with open('/media/cat/4TB1/donato/DON-002865/DON-002865_20210210/metadata.yaml') as file:
    doc = yaml.load(file, Loader=yaml.FullLoader)

    sort_file = yaml.dump(doc, sort_keys=True)
    print(sort_file)
# Out:
# - PDay: 90
